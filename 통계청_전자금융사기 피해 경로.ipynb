# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
if os.name == "posix":

    sns.set(font="AppleGothic")
elif os.name == "nt":

    sns.set(font="Malgun Gothic")
    

# %config InlineBackend.figure_format = 'retina'

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv("230127/전자금융사기_피해_경로_20230127171850.csv", encoding="cp949")
df
# Out:
#    특성별(1)        특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 0      전체            소계              22.8                   17.3
# 1      성별            남자              12.6                    3.9
# 2      성별            여자              37.2                   35.9
# 3     연령별        12~19세               0.0                    0.0
# 4     연령별           20대              21.3                    7.8
# 5     연령별           30대              58.0                    0.0
# 6     연령별           40대              24.9                   60.3
# 7     연령별           50대              16.0                    0.0
# 8     연령별           60대               0.0                    0.0
# 9     학력별          고등학생               0.0                    0.0
# 10    학력별        대학(원)생               9.3                   11.7
# 11    학력별         고졸 이하              41.1                    0.0
# 12    학력별         대졸 이상              21.9                   27.8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   특성별(1)                                          25 non-null     object
#  1   특성별(2)                                          25 non-null     object
#  2   이벤트를 가장한 홈페이지 접속                                25 non-null     float64
#  3   메일이나 게시판에 연결된 웹사이트 접속                           25 non-null     float64
#  4   공공·금융기관을 사칭한 전화를 통한 피싱                          25 non-null     float64
#  5   SNS를 통한 피싱                                      25 non-null     float64
#  6   인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  25 non-null     float64
#  7   금융기관 홈페이지를 가장한 웹사이트 접속                          25 non-null     float64
#  8   인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭             25 non-null     float64
# ...

# %%
df_sex = df[df["특성별(1)"] == "성별"]
df_sex
# Out:
#   특성별(1) 특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 1     성별     남자              12.6                    3.9
# 2     성별     여자              37.2                   35.9
#
#    공공·금융기관을 사칭한 전화를 통한 피싱  SNS를 통한 피싱  \
# 1                    37.1        19.2
# 2                    17.0         0.0
#
#    인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  금융기관 홈페이지를 가장한 웹사이트 접속  \
# 1                                            27.4                     3.2
# 2                                            19.0                     0.0
#
#    인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭
# 1                                 11.1
# 2                                 14.1

# %%
df_man = df[df["특성별(2)"] == "남자"]
df_man
# Out:
#   특성별(1) 특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 1     성별     남자              12.6                    3.9
#
#    공공·금융기관을 사칭한 전화를 통한 피싱  SNS를 통한 피싱  \
# 1                    37.1        19.2
#
#    인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  금융기관 홈페이지를 가장한 웹사이트 접속  \
# 1                                            27.4                     3.2
#
#    인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭
# 1                                 11.1

# %%
df_woman = df[df["특성별(2)"] == "여자"]
df_woman
# Out:
#   특성별(1) 특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 2     성별     여자              37.2                   35.9
#
#    공공·금융기관을 사칭한 전화를 통한 피싱  SNS를 통한 피싱  \
# 2                    17.0         0.0
#
#    인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  금융기관 홈페이지를 가장한 웹사이트 접속  \
# 2                                            19.0                     0.0
#
#    인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭
# 2                                 14.1

# %%
print(df_man.plot.barh(figsize=(10, 7)))
print(df_woman.plot.barh(figsize=(10, 7)))
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
df_age = df[df["특성별(1)"] == "연령별"]
df_age
# Out:
#   특성별(1)  특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 3    연령별  12~19세               0.0                    0.0
# 4    연령별     20대              21.3                    7.8
# 5    연령별     30대              58.0                    0.0
# 6    연령별     40대              24.9                   60.3
# 7    연령별     50대              16.0                    0.0
# 8    연령별     60대               0.0                    0.0
#
#    공공·금융기관을 사칭한 전화를 통한 피싱  SNS를 통한 피싱  \
# 3                     0.0         0.0
# 4                    26.4        16.5
# 5                     0.0        30.1
# 6                    21.4         0.0
# 7                    35.9        16.0
# 8                   100.0         0.0
#
#    인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  금융기관 홈페이지를 가장한 웹사이트 접속  \
# 3                                            46.0                     0.0
# 4                                            12.9                     0.0
# ...

# %%
df_10s = df[df["특성별(2)"] == "12~19세"]
df_10s
# Out:
#   특성별(1)  특성별(2)  이벤트를 가장한 홈페이지 접속  메일이나 게시판에 연결된 웹사이트 접속  \
# 3    연령별  12~19세               0.0                    0.0
#
#    공공·금융기관을 사칭한 전화를 통한 피싱  SNS를 통한 피싱  \
# 3                     0.0         0.0
#
#    인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치  금융기관 홈페이지를 가장한 웹사이트 접속  \
# 3                                            46.0                     0.0
#
#    인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭
# 3                                 54.0

# %%
df_10s.plot.barh(figsize=(10, 7))
# Out:
# <AxesSubplot:>

# %%
df["이벤트를 가장한 홈페이지 접속"].value_counts()
# Out:
# 0.0      4
# 100.0    2
# 50.0     2
# 22.8     1
# 28.8     1
# 31.4     1
# 7.7      1
# 10.3     1
# 30.2     1
# 18.7     1
# 21.9     1
# 12.6     1
# 41.1     1
# 9.3      1
# 16.0     1
# 24.9     1
# 58.0     1
# 21.3     1
# 37.2     1
# 15.8     1
# Name: 이벤트를 가장한 홈페이지 접속, dtype: int64

# %%
print(df[df["특성별(1)"] == "가구소득별"]["이벤트를 가장한 홈페이지 접속"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["메일이나 게시판에 연결된 웹사이트 접속"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["공공·금융기관을 사칭한 전화를 통한 피싱"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["SNS를 통한 피싱"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["금융기관 홈페이지를 가장한 웹사이트 접속"].sum())
print(df[df["특성별(1)"] == "가구소득별"]["인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭"].sum())
# Out:
# 126.0
# 36.8
# 127.5
# 27.799999999999997
# 71.6
# 10.7
# 46.9

# %%
df[df['특성별(1)'] == '가구소득별'].sum()
# Out:
# 특성별(1)                                                                    가구소득별가구소득별가구소득별가구소득별
# 특성별(2)                                            200~300만원 미만300~400만원 미만400~500만원 미만500만원 이상
# 이벤트를 가장한 홈페이지 접속                                                                         126.0
# 메일이나 게시판에 연결된 웹사이트 접속                                                                     36.8
# 공공·금융기관을 사칭한 전화를 통한 피싱                                                                   127.5
# SNS를 통한 피싱                                                                                27.8
# 인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치                                            71.6
# 금융기관 홈페이지를 가장한 웹사이트 접속                                                                    10.7
# 인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭                                                       46.9
# dtype: object

# %%
df["이벤트를 가장한 홈페이지 접속"].sum()
# Out:
# 708.0

# %% [raw]
# df.groupby(["특성별(1)", "특성별(2)"]).sum()

# %%
df[df['특성별(1)'] == '가구소득별'].sum()
# Out:
# 특성별(1)                                                                    가구소득별가구소득별가구소득별가구소득별
# 특성별(2)                                            200~300만원 미만300~400만원 미만400~500만원 미만500만원 이상
# 이벤트를 가장한 홈페이지 접속                                                                         126.0
# 메일이나 게시판에 연결된 웹사이트 접속                                                                     36.8
# 공공·금융기관을 사칭한 전화를 통한 피싱                                                                   127.5
# SNS를 통한 피싱                                                                                27.8
# 인스턴트메신저(카카오톡 라인 페이스북 메시지 등) 채팅 도중 프로그램 또는 앱 설치                                            71.6
# 금융기관 홈페이지를 가장한 웹사이트 접속                                                                    10.7
# 인스턴트메신저 채팅 또는 문자메시지 내 인터넷주소(URL) 클릭                                                       46.9
# dtype: object
